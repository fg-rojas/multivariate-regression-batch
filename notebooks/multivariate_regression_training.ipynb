# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.5.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.16.5)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)

# %%
import pandas as pd
# checking read data from collab.
pd.read_csv('/content/blind_test_data.csv').head()
# Out:
#     feature_0   feature_1   feature_2   feature_3   feature_4   feature_5  \
# 0  676.867615   32.518822  254.825875  502.268510  609.469688  497.624266
# 1  628.695228  426.163933  347.070280  431.106903  915.527507  301.699534
# 2  131.765943  323.839669  245.399775  181.814398  710.179159   59.117377
# 3  160.970195  489.712029   70.482159  309.486269  888.030604  412.655666
# 4  419.907137  216.625219  487.887860  253.704462  323.226862   65.744463
#
#     feature_6   feature_7   feature_8   feature_9  feature_10  feature_11  \
# 0  105.246239  269.045539  150.177005  312.649860  765.296227    0.237996
# 1    1.666992  306.733041  104.234252   63.242070  467.009734    6.608084
# 2  312.622788  687.965027  109.803179  381.169500  700.532108    1.822370
# 3  216.124989   47.415477  104.139145  326.462385  378.446187    1.686895
# 4  271.811469  527.726782  129.805782  168.429679  637.944633    0.948507
#
#    feature_12  feature_13  feature_14  feature_15  feature_16  feature_17  \
# 0  660.030637  147.059794   40.232132  464.424834  121.147466   68.284243
# 1  600.994184   43.619815   48.153926  457.256565   49.163652   85.511662
# 2  736.306092  138.759029   36.915389  436.174065   10.037994   62.631938
# 3  485.144327  143.668518   27.168148  309.715497  149.661493   66.415878
# 4  365.946758   72.337904   36.232169  302.772338  186.944884  106.514846
#
#    feature_18  feature_19
# 0   26.969870  314.461582
# 1   33.500538  819.537877
# 2    6.211169  341.361374
# 3   15.001753  539.087409
# 4    3.443809  364.341969

# %%
import warnings, time, json
warnings.filterwarnings("ignore")

import numpy as np, pandas as pd, joblib
from pathlib import Path
from datetime import datetime, timezone

from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import mutual_info_regression
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from xgboost import XGBRegressor
import optuna
from optuna.samplers import TPESampler

# ----------------- Config variables -----------------
DATA_DIR        = Path("/content")
TRAIN_PATH      = DATA_DIR / "training_data.csv"
BLIND_PATH      = DATA_DIR / "blind_test_data.csv"
MODEL_DIR       = Path("model"); MODEL_DIR.mkdir(exist_ok=True, parents=True)
MODEL_OUT       = MODEL_DIR / "model.pkl"
MANIFEST_OUT    = MODEL_DIR / "manifest.json"
PRED_OUT        = Path("target_pred.csv")

SEED            = 777
N_OUTER         = 4
N_INNER         = 3

N_TRIALS_HGBR   = 30
N_TRIALS_XGB    = 32
N_TRIALS_RF     = 32
N_TRIALS_ENET   = 32
TIMEOUT_SECS    = 420
PRUNER          = optuna.pruners.MedianPruner(n_startup_trials=4)

# XGBoost
XGB_TREE_METHOD = "hist"
XGB_N_JOBS      = 1

# Feature selection
CORR_TH         = 0.98
KEEP_RATIOS     = [1.0, 0.75, 0.5, 0.35, 0.25]
MIN_FEATS       = 8

rng = np.random.default_rng(SEED)

# utils functions
def rmse(y, p): return float(np.sqrt(mean_squared_error(y, p)))

def drop_constant_and_correlated(df_tr: pd.DataFrame, corr_th=0.99) -> list:
    # quita constantes
    keep = [c for c in df_tr.columns if df_tr[c].std(skipna=True) > 0.0]
    df = df_tr[keep]
    # quita colineales por |rho|>=th
    corr = df.corr(numeric_only=True).abs()
    upper = corr.where(np.triu(np.ones_like(corr), k=1).astype(bool))
    drop = [col for col in upper.columns if any(upper[col] >= corr_th)]
    return [c for c in df.columns if c not in drop]

def mi_topk(X: np.ndarray, y: np.ndarray, cols: list, keep_ratio: float, min_feats=MIN_FEATS) -> list:
    """
    Variable selection using the mutual information method (MI)
    """
    Xm = X.copy()
    med = np.nanmedian(Xm, axis=0)
    inds = np.where(np.isnan(Xm))
    if len(inds[0])>0: Xm[inds] = np.take(med, inds[1])
    mi = mutual_info_regression(Xm, y, random_state=SEED)
    order = np.argsort(mi)[::-1]
    k = max(min_feats, int(np.ceil(len(cols)*keep_ratio)))
    k = min(k, len(cols))
    return [cols[i] for i in order[:k]]

def suggest_params_hgbr(trial):
    return {
        "max_iter": trial.suggest_int("max_iter", 300, 1000),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 2e-1, log=True),
        "max_leaf_nodes": trial.suggest_int("max_leaf_nodes", 31, 255),
        "max_depth": trial.suggest_categorical("max_depth", [None, 6, 8, 10, 12]),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 5, 30),
        "l2_regularization": trial.suggest_float("l2_regularization", 1e-6, 1e-1, log=True),
        "max_bins": trial.suggest_categorical("max_bins", [128, 255]),
        "keep_ratio": trial.suggest_categorical("keep_ratio", KEEP_RATIOS),
    }

def suggest_params_xgb(trial):
    return {
        "n_estimators": trial.suggest_int("n_estimators", 400, 1600),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 2e-1, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 7),
        "subsample": trial.suggest_float("subsample", 0.7, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 3.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-6, 1e-1, log=True),
        "keep_ratio": trial.suggest_categorical("keep_ratio", KEEP_RATIOS),
    }

def suggest_params_rf(trial):
    return {
        "n_estimators": trial.suggest_int("n_estimators", 300, 900),
        "max_depth": trial.suggest_categorical("max_depth", [None, 6, 8, 10, 12, 14]),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 12),
        "max_features": trial.suggest_float("max_features", 0.4, 1.0),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
        "keep_ratio": trial.suggest_categorical("keep_ratio", KEEP_RATIOS),
    }

def suggest_params_enet(trial):
    return {
        "alpha": trial.suggest_float("alpha", 1e-4, 1e1, log=True),
        "l1_ratio": trial.suggest_float("l1_ratio", 0.05, 0.95),  #Mix de ambas 0=Ridge; 1=Lasso
        "max_iter": trial.suggest_int("max_iter", 2000, 6000),
        "keep_ratio": trial.suggest_categorical("keep_ratio", KEEP_RATIOS),
    }

def inner_cv_rmse(params, model_name, X_tr_full, y_tr_full, cols_prefiltered):
    kf = KFold(n_splits=N_INNER, shuffle=True, random_state=SEED)
    scores=[]
    keep_ratio = params.pop("keep_ratio")

    for tri, vai in kf.split(X_tr_full):
        X_tr, X_va = X_tr_full[tri], X_tr_full[vai]
        y_tr, y_va = y_tr_full[tri], y_tr_full[vai]

        # Selection MI
        cols_sel = mi_topk(X_tr, y_tr, cols_prefiltered, keep_ratio)
        sel_idx = [cols_prefiltered.index(c) for c in cols_sel]
        X_tr2, X_va2 = X_tr[:, sel_idx], X_va[:, sel_idx]

        if model_name == "xgb":
            mdl = XGBRegressor(random_state=SEED, tree_method=XGB_TREE_METHOD, n_jobs=XGB_N_JOBS,
                               eval_metric="rmse", **params)
            mdl.fit(X_tr2, y_tr)
            yhat = mdl.predict(X_va2)

        elif model_name == "hgbr":
            mdl = HistGradientBoostingRegressor(random_state=SEED, early_stopping=False, **params)
            mdl.fit(X_tr2, y_tr)
            yhat = mdl.predict(X_va2)

        elif model_name == "rf":
            mdl = RandomForestRegressor(random_state=SEED, n_jobs=1, **params)
            mdl.fit(X_tr2, y_tr)
            yhat = mdl.predict(X_va2)

        elif model_name == "enet":
            # Scaler for elastic net model
            mdl = Pipeline([
                ("scaler", StandardScaler(with_mean=True, with_std=True)),
                ("model", ElasticNet(alpha=params["alpha"], l1_ratio=params["l1_ratio"],
                                     max_iter=params["max_iter"], fit_intercept=True, random_state=None))
            ])
            mdl.fit(X_tr2, y_tr)
            yhat = mdl.predict(X_va2)

        else:
            raise ValueError("modelo no soportado")

        scores.append(rmse(y_va, yhat))

    params["keep_ratio"] = keep_ratio  # devolvemos
    return float(np.mean(scores))

def choose_params_of_best_fold(params_list, fold_scores):
    return params_list[int(np.argmin(fold_scores))]

def pct(x): return f"{100*x:.2f}%"

# ----------------- Carga datos -----------------

df = pd.read_csv(TRAIN_PATH)
feature_cols_all = [c for c in df.columns if c.startswith("feature_")]

X_all = df[feature_cols_all].to_numpy(dtype=np.float32)
y_all = df["target"].to_numpy(dtype=np.float32)

# ----------------- Nested CV con 4 modelos -----------------
outer = KFold(n_splits=N_OUTER, shuffle=True, random_state=SEED)

oof_h = np.zeros_like(y_all, dtype=float); fold_rmse_h=[]; best_params_h_by_fold=[]; sel_cols_h_by_fold=[]
oof_x = np.zeros_like(y_all, dtype=float); fold_rmse_x=[]; best_params_x_by_fold=[]; sel_cols_x_by_fold=[]
oof_r = np.zeros_like(y_all, dtype=float); fold_rmse_r=[]; best_params_r_by_fold=[]; sel_cols_r_by_fold=[]
oof_e = np.zeros_like(y_all, dtype=float); fold_rmse_e=[]; best_params_e_by_fold=[]; sel_cols_e_by_fold=[]

print(">>> Nested CV (4x3): feature selection and tuning per model")
t0 = time.time()

for k,(tr_idx, te_idx) in enumerate(outer.split(X_all),1):
    X_tr0, X_te0 = X_all[tr_idx], X_all[te_idx]
    y_tr0, y_te0 = y_all[tr_idx], y_all[te_idx]

    # Filter by correlation
    df_tr = pd.DataFrame(X_tr0, columns=feature_cols_all)
    cols_after_pref = drop_constant_and_correlated(df_tr, corr_th=CORR_TH)
    if len(cols_after_pref) < MIN_FEATS:
        cols_after_pref = feature_cols_all
    sel_idx_pref = [feature_cols_all.index(c) for c in cols_after_pref]
    X_tr_pref, X_te_pref = X_tr0[:, sel_idx_pref], X_te0[:, sel_idx_pref]

    # Fit for 1st model: HGBR
    def obj_h(trial):
        params = suggest_params_hgbr(trial)
        return inner_cv_rmse(params, "hgbr", X_tr_pref, y_tr0, cols_after_pref)

    st_h = optuna.create_study(direction="minimize", sampler=TPESampler(seed=SEED), pruner=PRUNER)
    st_h.optimize(obj_h, n_trials=N_TRIALS_HGBR, timeout=TIMEOUT_SECS, show_progress_bar=False)
    hp_h = st_h.best_params; best_params_h_by_fold.append(hp_h.copy())
    cols_h = mi_topk(X_tr_pref, y_tr0, cols_after_pref, keep_ratio=hp_h["keep_ratio"])
    sel_cols_h_by_fold.append(cols_h)
    idx_h = [cols_after_pref.index(c) for c in cols_h]
    h = HistGradientBoostingRegressor(random_state=SEED, early_stopping=False,
                                      **{k:v for k,v in hp_h.items() if k!="keep_ratio"})
    h.fit(X_tr_pref[:, idx_h], y_tr0)
    pred_h = h.predict(X_te_pref[:, idx_h])
    oof_h[te_idx] = pred_h; fold_rmse_h.append(rmse(y_te0, pred_h))

    # Fit for 2nd model: XGB
    def obj_x(trial):
        params = suggest_params_xgb(trial)
        return inner_cv_rmse(params, "xgb", X_tr_pref, y_tr0, cols_after_pref)

    st_x = optuna.create_study(direction="minimize", sampler=TPESampler(seed=SEED), pruner=PRUNER)
    st_x.optimize(obj_x, n_trials=N_TRIALS_XGB, timeout=TIMEOUT_SECS, show_progress_bar=False)
    hp_x = st_x.best_params; best_params_x_by_fold.append(hp_x.copy())
    cols_x = mi_topk(X_tr_pref, y_tr0, cols_after_pref, keep_ratio=hp_x["keep_ratio"])
    sel_cols_x_by_fold.append(cols_x)
    idx_x = [cols_after_pref.index(c) for c in cols_x]
    x = XGBRegressor(random_state=SEED, tree_method=XGB_TREE_METHOD, n_jobs=XGB_N_JOBS,
                     eval_metric="rmse",
                     **{k:v for k,v in hp_x.items() if k!="keep_ratio"})
    x.fit(X_tr_pref[:, idx_x], y_tr0)
    pred_x = x.predict(X_te_pref[:, idx_x])
    oof_x[te_idx] = pred_x; fold_rmse_x.append(rmse(y_te0, pred_x))

    # Fit for 3rd model: RandomForest
    def obj_r(trial):
        params = suggest_params_rf(trial)
        return inner_cv_rmse(params, "rf", X_tr_pref, y_tr0, cols_after_pref)

    st_r = optuna.create_study(direction="minimize", sampler=TPESampler(seed=SEED), pruner=PRUNER)
    st_r.optimize(obj_r, n_trials=N_TRIALS_RF, timeout=TIMEOUT_SECS, show_progress_bar=False)
    hp_r = st_r.best_params; best_params_r_by_fold.append(hp_r.copy())
    cols_r = mi_topk(X_tr_pref, y_tr0, cols_after_pref, keep_ratio=hp_r["keep_ratio"])
    sel_cols_r_by_fold.append(cols_r)
    idx_r = [cols_after_pref.index(c) for c in cols_r]
    r = RandomForestRegressor(random_state=SEED, n_jobs=1, **{k:v for k,v in hp_r.items() if k!="keep_ratio"})
    r.fit(X_tr_pref[:, idx_r], y_tr0)
    pred_r = r.predict(X_te_pref[:, idx_r])
    oof_r[te_idx] = pred_r; fold_rmse_r.append(rmse(y_te0, pred_r))

    # Fit for 4th model: ElasticNet with Scaler
    def obj_e(trial):
        params = suggest_params_enet(trial)
        return inner_cv_rmse(params, "enet", X_tr_pref, y_tr0, cols_after_pref)

    st_e = optuna.create_study(direction="minimize", sampler=TPESampler(seed=SEED), pruner=PRUNER)
    st_e.optimize(obj_e, n_trials=N_TRIALS_ENET, timeout=TIMEOUT_SECS, show_progress_bar=False)
    hp_e = st_e.best_params; best_params_e_by_fold.append(hp_e.copy())
    cols_e = mi_topk(X_tr_pref, y_tr0, cols_after_pref, keep_ratio=hp_e["keep_ratio"])
    sel_cols_e_by_fold.append(cols_e)
    idx_e = [cols_after_pref.index(c) for c in cols_e]
    e = Pipeline([
        ("scaler", StandardScaler(with_mean=True, with_std=True)),
        ("model", ElasticNet(alpha=hp_e["alpha"], l1_ratio=hp_e["l1_ratio"],
                             max_iter=hp_e["max_iter"], fit_intercept=True))
    ])
    e.fit(X_tr_pref[:, idx_e], y_tr0)
    pred_e = e.predict(X_te_pref[:, idx_e])
    oof_e[te_idx] = pred_e; fold_rmse_e.append(rmse(y_te0, pred_e))

    print(f"[Fold {k}/{N_OUTER}] RMSE HGBR={fold_rmse_h[-1]:.4f} (#{len(cols_h)}) | "
          f"XGB={fold_rmse_x[-1]:.4f} (#{len(cols_x)}) | "
          f"RF={fold_rmse_r[-1]:.4f} (#{len(cols_r)}) | "
          f"ENet={fold_rmse_e[-1]:.4f} (#{len(cols_e)})")

elapsed = time.time()-t0

# OOF per model
def oof_summary(name, oof_vec, fold_scores, sel_cols_list):
    return {
        "name": name,
        "oof_rmse": rmse(y_all, oof_vec),
        "mean": float(np.mean(fold_scores)),
        "std": float(np.std(fold_scores)),
        "median_feats": int(np.median([len(c) for c in sel_cols_list])) if sel_cols_list else None
    }

sum_h = oof_summary("HGBR", oof_h, fold_rmse_h, sel_cols_h_by_fold)
sum_x = oof_summary("XGB",  oof_x, fold_rmse_x, sel_cols_x_by_fold)
sum_r = oof_summary("RF",   oof_r, fold_rmse_r, sel_cols_r_by_fold)
sum_e = oof_summary("ENet", oof_e, fold_rmse_e, sel_cols_e_by_fold)

print("\n >>>>> OOF Summary <<<<<")
for s in [sum_h, sum_x, sum_r, sum_e]:
    print(f"{s['name']:5s} OOF RMSE: {s['oof_rmse']:.6f} | mean={s['mean']:.6f} ± {s['std']:.6f} | "
          f"median #feats={s['median_feats']}")

# Final model
candidates = [sum_h, sum_x, sum_r, sum_e]
best = min(candidates, key=lambda d: d["oof_rmse"])

# Selection of parsimonious model in case of similar performance
def rel_gap(a, b): return abs(a-b)/min(a,b) if min(a,b)>0 else 0.0
second = sorted(candidates, key=lambda d: d["oof_rmse"])[1]
if rel_gap(best["oof_rmse"], second["oof_rmse"]) < 0.005:
    # Select the one with less features
    if best["median_feats"] is not None and second["median_feats"] is not None:
        if second["median_feats"] < best["median_feats"]:
            best = second

print("\n >>>>> FINAL MODEL <<<<<")
print(f"Selected: {best['name']} with OOF RMSE={best['oof_rmse']:.6f}")

# Fit and persist of final model
df_all = pd.DataFrame(X_all, columns=feature_cols_all)
cols_global_pref = drop_constant_and_correlated(df_all, corr_th=CORR_TH)
if len(cols_global_pref) < MIN_FEATS: cols_global_pref = feature_cols_all
idx_pref_all = [feature_cols_all.index(c) for c in cols_global_pref]
X_pref_all = X_all[:, idx_pref_all]

# get choosen parameter for final model
def choose_params(params_by_fold, fold_scores):
    return params_by_fold[int(np.argmin(fold_scores))] if params_by_fold else {}

hp_h_final = choose_params(best_params_h_by_fold, fold_rmse_h)
hp_x_final = choose_params(best_params_x_by_fold, fold_rmse_x)
hp_r_final = choose_params(best_params_r_by_fold, fold_rmse_r)
hp_e_final = choose_params(best_params_e_by_fold, fold_rmse_e)

# Selección global por MI según keep_ratio del ganador de cada modelo
cols_h_final = mi_topk(X_pref_all, y_all, cols_global_pref, hp_h_final.get("keep_ratio", 1.0)) if hp_h_final else cols_global_pref
cols_x_final = mi_topk(X_pref_all, y_all, cols_global_pref, hp_x_final.get("keep_ratio", 1.0)) if hp_x_final else cols_global_pref
cols_r_final = mi_topk(X_pref_all, y_all, cols_global_pref, hp_r_final.get("keep_ratio", 1.0)) if hp_r_final else cols_global_pref
cols_e_final = mi_topk(X_pref_all, y_all, cols_global_pref, hp_e_final.get("keep_ratio", 1.0)) if hp_e_final else cols_global_pref

chosen_name = best["name"]
if chosen_name == "HGBR":
    Xf = X_pref_all[:, [cols_global_pref.index(c) for c in cols_h_final]]
    estimator = HistGradientBoostingRegressor(random_state=SEED, early_stopping=False,
                                              **{k:v for k,v in hp_h_final.items() if k!="keep_ratio"})
    estimator.fit(Xf, y_all)
    features_final = cols_h_final
    model_dict = {"model":"HGBR","estimator":estimator,"features":features_final}

elif chosen_name == "XGB":
    Xf = X_pref_all[:, [cols_global_pref.index(c) for c in cols_x_final]]
    estimator = XGBRegressor(random_state=SEED, tree_method=XGB_TREE_METHOD, n_jobs=XGB_N_JOBS,
                             eval_metric="rmse",
                             **{k:v for k,v in hp_x_final.items() if k!="keep_ratio"})
    estimator.fit(Xf, y_all)
    features_final = cols_x_final
    model_dict = {"model":"XGB","estimator":estimator,"features":features_final}

elif chosen_name == "RF":
    Xf = X_pref_all[:, [cols_global_pref.index(c) for c in cols_r_final]]
    estimator = RandomForestRegressor(random_state=SEED, n_jobs=1,
                                      **{k:v for k,v in hp_r_final.items() if k!="keep_ratio"})
    estimator.fit(Xf, y_all)
    features_final = cols_r_final
    model_dict = {"model":"RF","estimator":estimator,"features":features_final}

else:  # Elastic Net
    Xf = X_pref_all[:, [cols_global_pref.index(c) for c in cols_e_final]]
    estimator = Pipeline([
        ("scaler", StandardScaler(with_mean=True, with_std=True)),
        ("model", ElasticNet(alpha=hp_e_final["alpha"], l1_ratio=hp_e_final["l1_ratio"],
                             max_iter=hp_e_final["max_iter"], fit_intercept=True))
    ])
    estimator.fit(Xf, y_all)
    features_final = cols_e_final
    model_dict = {"model":"ENet","estimator":estimator,"features":features_final}

joblib.dump(model_dict, MODEL_OUT)
print(f"\n Saved: {MODEL_OUT.resolve()}")

# Predicciones blind si existe
if BLIND_PATH.exists():
    blind = pd.read_csv(BLIND_PATH)
    miss = [c for c in features_final if c not in blind.columns]
    if miss:
        print(f"[WARN] Faltan columnas en blind: {miss[:8]}{'...' if len(miss)>8 else ''}")
    else:
        Xb = blind[features_final].to_numpy(dtype=np.float32)
        m = joblib.load(MODEL_OUT)
        yb = m["estimator"].predict(Xb) if isinstance(m, dict) else m.predict(Xb)
        pd.DataFrame({"target_pred": yb}).to_csv(PRED_OUT, index=False)
        print(f"Predicciones: {PRED_OUT.resolve()}")
# Out:
# [I 2025-10-15 02:28:49,580] A new study created in memory with name: no-name-a7f0fb79-56ec-4c8a-80d7-779fe5512d97
# >>> Nested CV (4x3): feature selection and tuning per model
# [I 2025-10-15 02:28:54,217] Trial 0 finished with value: 2.9522488910438214 and parameters: {'max_iter': 407, 'learning_rate': 0.004962855477056064, 'max_leaf_nodes': 44, 'max_depth': 8, 'min_samples_leaf': 11, 'l2_regularization': 0.0016601466766433721, 'max_bins': 128, 'keep_ratio': 0.5}. Best is trial 0 with value: 2.9522488910438214.
# [I 2025-10-15 02:28:57,319] Trial 1 finished with value: 2.444512528290961 and parameters: {'max_iter': 687, 'learning_rate': 0.004155804010335765, 'max_leaf_nodes': 114, 'max_depth': 12, 'min_samples_leaf': 27, 'l2_regularization': 0.0012932846459544705, 'max_bins': 128, 'keep_ratio': 1.0}. Best is trial 1 with value: 2.444512528290961.
# [I 2025-10-15 02:28:59,320] Trial 2 finished with value: 3.700695309116584 and parameters: {'max_iter': 673, 'learning_rate': 0.0010730669610487867, 'max_leaf_nodes': 148, 'max_depth': None, 'min_samples_leaf': 23, 'l2_regularization': 0.00020772432462140656, 'max_bins': 128, 'keep_ratio': 0.35}. Best is trial 1 with value: 2.444512528290961.
# [I 2025-10-15 02:29:03,027] Trial 3 finished with value: 2.6724158024382523 and parameters: {'max_iter': 777, 'learning_rate': 0.0068193111565296805, 'max_leaf_nodes': 108, 'max_depth': 10, 'min_samples_leaf': 13, 'l2_regularization': 0.00043662763608431714, 'max_bins': 255, 'keep_ratio': 0.35}. Best is trial 1 with value: 2.444512528290961.
# [I 2025-10-15 02:29:08,854] Trial 4 finished with value: 2.2669282600213685 and parameters: {'max_iter': 894, 'learning_rate': 0.018121034100333097, 'max_leaf_nodes': 110, 'max_depth': 8, 'min_samples_leaf': 12, 'l2_regularization': 3.22286007206463e-05, 'max_bins': 255, 'keep_ratio': 1.0}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:10,130] Trial 5 finished with value: 2.58771597675839 and parameters: {'max_iter': 305, 'learning_rate': 0.060698516787257066, 'max_leaf_nodes': 223, 'max_depth': 12, 'min_samples_leaf': 25, 'l2_regularization': 1.6377122104891931e-06, 'max_bins': 255, 'keep_ratio': 0.35}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:13,091] Trial 6 finished with value: 3.8629072027158684 and parameters: {'max_iter': 472, 'learning_rate': 0.001109077884736705, 'max_leaf_nodes': 189, 'max_depth': 8, 'min_samples_leaf': 14, 'l2_regularization': 0.00045757759914869217, 'max_bins': 255, 'keep_ratio': 1.0}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:14,227] Trial 7 finished with value: 2.2871295347188845 and parameters: {'max_iter': 374, 'learning_rate': 0.09202622060601795, 'max_leaf_nodes': 147, 'max_depth': 6, 'min_samples_leaf': 25, 'l2_regularization': 3.7481308989188146e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:18,004] Trial 8 finished with value: 3.2498053531802182 and parameters: {'max_iter': 886, 'learning_rate': 0.0014151935175565477, 'max_leaf_nodes': 174, 'max_depth': 12, 'min_samples_leaf': 14, 'l2_regularization': 0.00012011528848433134, 'max_bins': 128, 'keep_ratio': 0.5}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:24,545] Trial 9 finished with value: 2.7348198244995046 and parameters: {'max_iter': 868, 'learning_rate': 0.00856837682627823, 'max_leaf_nodes': 146, 'max_depth': 12, 'min_samples_leaf': 9, 'l2_regularization': 0.008560969831550923, 'max_bins': 255, 'keep_ratio': 0.35}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:30,565] Trial 10 finished with value: 2.7899592899488006 and parameters: {'max_iter': 956, 'learning_rate': 0.028033922460499846, 'max_leaf_nodes': 47, 'max_depth': 8, 'min_samples_leaf': 5, 'l2_regularization': 1.816959517998745e-05, 'max_bins': 255, 'keep_ratio': 0.25}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:32,350] Trial 11 finished with value: 2.378350841771157 and parameters: {'max_iter': 521, 'learning_rate': 0.19278258994975797, 'max_leaf_nodes': 106, 'max_depth': 6, 'min_samples_leaf': 20, 'l2_regularization': 2.91946104979859e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 4 with value: 2.2669282600213685.
# [I 2025-10-15 02:29:34,696] Trial 12 finished with value: 2.252624418983561 and parameters: {'max_iter': 587, 'learning_rate': 0.06845626891202702, 'max_leaf_nodes': 87, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 1.7544407807664286e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 12 with value: 2.252624418983561.
# [I 2025-10-15 02:29:36,474] Trial 13 finished with value: 2.2576097326561606 and parameters: {'max_iter': 578, 'learning_rate': 0.022273713483360748, 'max_leaf_nodes': 76, 'max_depth': 6, 'min_samples_leaf': 29, 'l2_regularization': 2.1416250465164186e-05, 'max_bins': 255, 'keep_ratio': 0.75}. Best is trial 12 with value: 2.252624418983561.
# [I 2025-10-15 02:29:37,976] Trial 14 finished with value: 2.244255512366554 and parameters: {'max_iter': 567, 'learning_rate': 0.049277353271325125, 'max_leaf_nodes': 74, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 1.879532502567399e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 14 with value: 2.244255512366554.
# [I 2025-10-15 02:29:39,577] Trial 15 finished with value: 2.250761601406835 and parameters: {'max_iter': 591, 'learning_rate': 0.06533506841975961, 'max_leaf_nodes': 71, 'max_depth': 6, 'min_samples_leaf': 29, 'l2_regularization': 9.496817225246703e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 14 with value: 2.244255512366554.
# [I 2025-10-15 02:29:41,729] Trial 16 finished with value: 2.3112185418121625 and parameters: {'max_iter': 741, 'learning_rate': 0.039791878203549354, 'max_leaf_nodes': 31, 'max_depth': 6, 'min_samples_leaf': 21, 'l2_regularization': 6.8955764575480466e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 14 with value: 2.244255512366554.
# [I 2025-10-15 02:29:43,741] Trial 17 finished with value: 2.680500130464209 and parameters: {'max_iter': 571, 'learning_rate': 0.15709306819049298, 'max_leaf_nodes': 67, 'max_depth': 10, 'min_samples_leaf': 18, 'l2_regularization': 0.08485501187431774, 'max_bins': 128, 'keep_ratio': 0.25}. Best is trial 14 with value: 2.244255512366554.
# [I 2025-10-15 02:29:45,510] Trial 18 finished with value: 2.2643339175695076 and parameters: {'max_iter': 454, 'learning_rate': 0.09947258963539814, 'max_leaf_nodes': 71, 'max_depth': None, 'min_samples_leaf': 27, 'l2_regularization': 1.0146150565869057e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 14 with value: 2.244255512366554.
# [I 2025-10-15 02:29:47,801] Trial 19 finished with value: 2.2311569161256464 and parameters: {'max_iter': 636, 'learning_rate': 0.04268372177461566, 'max_leaf_nodes': 91, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 8.193238034703977e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 19 with value: 2.2311569161256464.
# [I 2025-10-15 02:29:50,199] Trial 20 finished with value: 2.298197498071817 and parameters: {'max_iter': 760, 'learning_rate': 0.035895749963801765, 'max_leaf_nodes': 239, 'max_depth': 6, 'min_samples_leaf': 17, 'l2_regularization': 6.829185565026577e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 19 with value: 2.2311569161256464.
# [I 2025-10-15 02:29:51,882] Trial 21 finished with value: 2.23087657056064 and parameters: {'max_iter': 626, 'learning_rate': 0.052433517181546305, 'max_leaf_nodes': 88, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 7.01482018846512e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:29:53,600] Trial 22 finished with value: 2.265398578145488 and parameters: {'max_iter': 628, 'learning_rate': 0.042877273721249734, 'max_leaf_nodes': 91, 'max_depth': 6, 'min_samples_leaf': 27, 'l2_regularization': 6.623171247306329e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:29:54,999] Trial 23 finished with value: 2.3324109261467076 and parameters: {'max_iter': 506, 'learning_rate': 0.012366610725921118, 'max_leaf_nodes': 126, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 5.1259235112023334e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:29:56,760] Trial 24 finished with value: 2.7504245953423645 and parameters: {'max_iter': 692, 'learning_rate': 0.11156070218795382, 'max_leaf_nodes': 54, 'max_depth': 6, 'min_samples_leaf': 24, 'l2_regularization': 0.00018533498668574445, 'max_bins': 128, 'keep_ratio': 0.25}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:29:59,598] Trial 25 finished with value: 2.2862371374402257 and parameters: {'max_iter': 636, 'learning_rate': 0.045475939895609094, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 28, 'l2_regularization': 0.0006861546209308633, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:30:01,833] Trial 26 finished with value: 2.590580060666989 and parameters: {'max_iter': 822, 'learning_rate': 0.014553365305434829, 'max_leaf_nodes': 90, 'max_depth': 6, 'min_samples_leaf': 23, 'l2_regularization': 0.004485336831659095, 'max_bins': 128, 'keep_ratio': 0.5}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:30:03,547] Trial 27 finished with value: 2.2758976593282654 and parameters: {'max_iter': 537, 'learning_rate': 0.026614305558043977, 'max_leaf_nodes': 170, 'max_depth': 10, 'min_samples_leaf': 26, 'l2_regularization': 8.981622640344176e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02:30:05,411] Trial 28 finished with value: 2.2723146121675 and parameters: {'max_iter': 719, 'learning_rate': 0.13356558433638807, 'max_leaf_nodes': 92, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 0.00011106623058286111, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.23087657056064.
# [I 2025-10-15 02
# [I 2025-10-15 02:32:34,362] A new study created in memory with name: no-name-d84501b5-54f9-4361-b816-4ceae456c70f
# [I 2025-10-15 02:32:36,793] Trial 0 finished with value: 3.0130741565858385 and parameters: {'n_estimators': 391, 'max_depth': 12, 'min_samples_leaf': 10, 'max_features': 0.561523039883316, 'bootstrap': True, 'keep_ratio': 0.35}. Best is trial 0 with value: 3.0130741565858385.
# [I 2025-10-15 02:32:44,203] Trial 1 finished with value: 2.8714713891181565 and parameters: {'n_estimators': 709, 'max_depth': None, 'min_samples_leaf': 3, 'max_features': 0.7665465588130735, 'bootstrap': True, 'keep_ratio': 0.5}. Best is trial 1 with value: 2.8714713891181565.
# [I 2025-10-15 02:32:52,553] Trial 2 finished with value: 2.750188621258058 and parameters: {'n_estimators': 611, 'max_depth': 12, 'min_samples_leaf': 2, 'max_features': 0.5775236164524532, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 2 with value: 2.750188621258058.
# [I 2025-10-15 02:33:01,474] Trial 3 finished with value: 2.743470604333458 and parameters: {'n_estimators': 583, 'max_depth': None, 'min_samples_leaf': 1, 'max_features': 0.6491486138859309, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.743470604333458.
# [I 2025-10-15 02:33:04,638] Trial 4 finished with value: 2.886174519175585 and parameters: {'n_estimators': 358, 'max_depth': 10, 'min_samples_leaf': 9, 'max_features': 0.45631100700191085, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 3 with value: 2.743470604333458.
# [I 2025-10-15 02:33:11,217] Trial 5 finished with value: 2.8927545506814965 and parameters: {'n_estimators': 681, 'max_depth': 14, 'min_samples_leaf': 11, 'max_features': 0.4789196901078193, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.743470604333458.
# [I 2025-10-15 02:33:29,313] Trial 6 finished with value: 2.6838080966417643 and parameters: {'n_estimators': 886, 'max_depth': 10, 'min_samples_leaf': 1, 'max_features': 0.8235932881616793, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:33:39,740] Trial 7 finished with value: 3.0807841302640324 and parameters: {'n_estimators': 478, 'max_depth': 6, 'min_samples_leaf': 2, 'max_features': 0.9120954329667595, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:33:43,609] Trial 8 finished with value: 3.22440879599495 and parameters: {'n_estimators': 368, 'max_depth': None, 'min_samples_leaf': 5, 'max_features': 0.9015906654375635, 'bootstrap': False, 'keep_ratio': 0.25}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:33:51,611] Trial 9 finished with value: 2.700045175482915 and parameters: {'n_estimators': 524, 'max_depth': 14, 'min_samples_leaf': 4, 'max_features': 0.791758436095749, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:33:59,215] Trial 10 finished with value: 2.9224823268723967 and parameters: {'n_estimators': 863, 'max_depth': 10, 'min_samples_leaf': 7, 'max_features': 0.9818366028617853, 'bootstrap': True, 'keep_ratio': 0.35}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:34:11,224] Trial 11 finished with value: 2.735050990959978 and parameters: {'n_estimators': 863, 'max_depth': 8, 'min_samples_leaf': 5, 'max_features': 0.7867153374991968, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:34:18,381] Trial 12 finished with value: 2.7006127816511474 and parameters: {'n_estimators': 506, 'max_depth': 14, 'min_samples_leaf': 4, 'max_features': 0.7896545242722215, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:34:28,412] Trial 13 finished with value: 2.7726532476336914 and parameters: {'n_estimators': 792, 'max_depth': 14, 'min_samples_leaf': 7, 'max_features': 0.7073838007704448, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:34:35,055] Trial 14 finished with value: 2.8656638512475214 and parameters: {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 1, 'max_features': 0.8751319466949454, 'bootstrap': True, 'keep_ratio': 0.5}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:34:41,384] Trial 15 finished with value: 2.868808696835353 and parameters: {'n_estimators': 741, 'max_depth': 8, 'min_samples_leaf': 4, 'max_features': 0.8368308068660977, 'bootstrap': True, 'keep_ratio': 0.25}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:34:49,332] Trial 16 finished with value: 2.7716869944584173 and parameters: {'n_estimators': 606, 'max_depth': 6, 'min_samples_leaf': 6, 'max_features': 0.7013358615077658, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:35:00,209] Trial 17 finished with value: 2.691334544547333 and parameters: {'n_estimators': 801, 'max_depth': 10, 'min_samples_leaf': 3, 'max_features': 0.631840619527922, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:35:19,817] Trial 18 finished with value: 2.6901964058887757 and parameters: {'n_estimators': 899, 'max_depth': 10, 'min_samples_leaf': 1, 'max_features': 0.6179516350124179, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:35:30,193] Trial 19 finished with value: 2.9302626349384227 and parameters: {'n_estimators': 889, 'max_depth': 10, 'min_samples_leaf': 1, 'max_features': 0.5240366848013415, 'bootstrap': False, 'keep_ratio': 0.5}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:35:34,737] Trial 20 finished with value: 2.9635419173500446 and parameters: {'n_estimators': 801, 'max_depth': 10, 'min_samples_leaf': 8, 'max_features': 0.4046345976578777, 'bootstrap': False, 'keep_ratio': 0.35}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:35:51,134] Trial 21 finished with value: 2.690264497000071 and parameters: {'n_estimators': 810, 'max_depth': 10, 'min_samples_leaf': 2, 'max_features': 0.6405666590685178, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:36:08,477] Trial 22 finished with value: 2.6921090661027383 and parameters: {'n_estimators': 899, 'max_depth': 10, 'min_samples_leaf': 2, 'max_features': 0.6390762449975539, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:36:29,759] Trial 23 finished with value: 2.7476211247349416 and parameters: {'n_estimators': 843, 'max_depth': 10, 'min_samples_leaf': 1, 'max_features': 0.7410514227945543, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 6 with value: 2.6838080966417643.
# [I 2025-10-15 02:36:42,239] Trial 24 finished with value: 2.670332869079257 and parameters: {'n_estimators': 744, 'max_depth': 10, 'min_samples_leaf': 3, 'max_features': 0.5993669347466507, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02:36:48,083] Trial 25 finished with value: 2.9050484107639165 and parameters: {'n_estimators': 745, 'max_depth': 10, 'min_samples_leaf': 3, 'max_features': 0.560108083459631, 'bootstrap': False, 'keep_ratio': 0.25}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02:37:00,332] Trial 26 finished with value: 2.690249001906441 and parameters: {'n_estimators': 677, 'max_depth': 10, 'min_samples_leaf': 3, 'max_features': 0.6085965151275897, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02:37:13,072] Trial 27 finished with value: 2.7940165293833488 and parameters: {'n_estimators': 757, 'max_depth': 6, 'min_samples_leaf': 1, 'max_features': 0.6819771538636332, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02:37:32,756] Trial 28 finished with value: 3.2488049318748184 and parameters: {'n_estimators': 839, 'max_depth': 8, 'min_samples_leaf': 5, 'max_features': 0.9796142156535375, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02:37:36,791] Trial 29 finished with value: 2.9983898157941233 and parameters: {'n_estimators': 667, 'max_depth': 12, 'min_samples_leaf': 12, 'max_features': 0.5476363860794261, 'bootstrap': False, 'keep_ratio': 0.35}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02:37:48,605] Trial 30 finished with value: 2.7506488235822104 and parameters: {'n_estimators': 899, 'max_depth': 12, 'min_samples_leaf': 2, 'max_features': 0.5053608703851358, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 24 with value: 2.670332869079257.
# [I 2025-10-15 02
. Best is trial 24 with value: 2.808401408795092.
# [I 2025-10-15 02:38:13,047] Trial 31 finished with value: 2.822660872602927 and parameters: {'alpha': 0.024229210807753154, 'l1_ratio': 0.8206215808835449, 'max_iter': 2976, 'keep_ratio': 1.0}. Best is trial 24 with value: 2.808401408795092.
# [I 2025-10-15 02:38:13,148] A new study created in memory with name: no-name-3e9309bc-a4aa-4bde-b0e8-fd3daf5d584b
# [Fold 1/4] RMSE HGBR=2.7693 (#15) | XGB=2.0748 (#20) | RF=2.5999 (#20) | ENet=2.8950 (#20)
# [I 2025-10-15 02:38:15,389] Trial 0 finished with value: 2.719064854006253 and parameters: {'max_iter': 407, 'learning_rate': 0.004962855477056064, 'max_leaf_nodes': 44, 'max_depth': 8, 'min_samples_leaf': 11, 'l2_regularization': 0.0016601466766433721, 'max_bins': 128, 'keep_ratio': 0.5}. Best is trial 0 with value: 2.719064854006253.
# [I 2025-10-15 02:38:17,566] Trial 1 finished with value: 2.4869302730934186 and parameters: {'max_iter': 687, 'learning_rate': 0.004155804010335765, 'max_leaf_nodes': 114, 'max_depth': 12, 'min_samples_leaf': 27, 'l2_regularization': 0.0012932846459544705, 'max_bins': 128, 'keep_ratio': 1.0}. Best is trial 1 with value: 2.4869302730934186.
# [I 2025-10-15 02:38:19,889] Trial 2 finished with value: 3.742966135548915 and parameters: {'max_iter': 673, 'learning_rate': 0.0010730669610487867, 'max_leaf_nodes': 148, 'max_depth': None, 'min_samples_leaf': 23, 'l2_regularization': 0.00020772432462140656, 'max_bins': 128, 'keep_ratio': 0.35}. Best is trial 1 with value: 2.4869302730934186.
# [I 2025-10-15 02:38:24,135] Trial 3 finished with value: 2.791524414859263 and parameters: {'max_iter': 777, 'learning_rate': 0.0068193111565296805, 'max_leaf_nodes': 108, 'max_depth': 10, 'min_samples_leaf': 13, 'l2_regularization': 0.00043662763608431714, 'max_bins': 255, 'keep_ratio': 0.35}. Best is trial 1 with value: 2.4869302730934186.
# [I 2025-10-15 02:38:29,280] Trial 4 finished with value: 2.3006267066587927 and parameters: {'max_iter': 894, 'learning_rate': 0.018121034100333097, 'max_leaf_nodes': 110, 'max_depth': 8, 'min_samples_leaf': 12, 'l2_regularization': 3.22286007206463e-05, 'max_bins': 255, 'keep_ratio': 1.0}. Best is trial 4 with value: 2.3006267066587927.
# [I 2025-10-15 02:38:30,339] Trial 5 finished with value: 2.7914588199153507 and parameters: {'max_iter': 305, 'learning_rate': 0.060698516787257066, 'max_leaf_nodes': 223, 'max_depth': 12, 'min_samples_leaf': 25, 'l2_regularization': 1.6377122104891931e-06, 'max_bins': 255, 'keep_ratio': 0.35}. Best is trial 4 with value: 2.3006267066587927.
# [I 2025-10-15 02:38:34,231] Trial 6 finished with value: 3.825594621395322 and parameters: {'max_iter': 472, 'learning_rate': 0.001109077884736705, 'max_leaf_nodes': 189, 'max_depth': 8, 'min_samples_leaf': 14, 'l2_regularization': 0.00045757759914869217, 'max_bins': 255, 'keep_ratio': 1.0}. Best is trial 4 with value: 2.3006267066587927.
# [I 2025-10-15 02:38:35,383] Trial 7 finished with value: 2.117535401895665 and parameters: {'max_iter': 374, 'learning_rate': 0.09202622060601795, 'max_leaf_nodes': 147, 'max_depth': 6, 'min_samples_leaf': 25, 'l2_regularization': 3.7481308989188146e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:39,174] Trial 8 finished with value: 3.07378030126819 and parameters: {'max_iter': 886, 'learning_rate': 0.0014151935175565477, 'max_leaf_nodes': 174, 'max_depth': 12, 'min_samples_leaf': 14, 'l2_regularization': 0.00012011528848433134, 'max_bins': 128, 'keep_ratio': 0.5}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:45,007] Trial 9 finished with value: 2.7911571705409703 and parameters: {'max_iter': 868, 'learning_rate': 0.00856837682627823, 'max_leaf_nodes': 146, 'max_depth': 12, 'min_samples_leaf': 9, 'l2_regularization': 0.008560969831550923, 'max_bins': 255, 'keep_ratio': 0.35}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:47,187] Trial 10 finished with value: 2.1940960241235206 and parameters: {'max_iter': 527, 'learning_rate': 0.19949305760259786, 'max_leaf_nodes': 35, 'max_depth': 6, 'min_samples_leaf': 20, 'l2_regularization': 1.0845839362311285e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:48,838] Trial 11 finished with value: 2.1723837389577896 and parameters: {'max_iter': 521, 'learning_rate': 0.1960862607101095, 'max_leaf_nodes': 34, 'max_depth': 6, 'min_samples_leaf': 20, 'l2_regularization': 1.0089473194665358e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:50,387] Trial 12 finished with value: 2.1856359993752164 and parameters: {'max_iter': 561, 'learning_rate': 0.18873834289492, 'max_leaf_nodes': 66, 'max_depth': 6, 'min_samples_leaf': 29, 'l2_regularization': 9.40118535977105e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:51,910] Trial 13 finished with value: 2.847101066396521 and parameters: {'max_iter': 323, 'learning_rate': 0.06539753549588005, 'max_leaf_nodes': 81, 'max_depth': 6, 'min_samples_leaf': 5, 'l2_regularization': 8.926425094182913e-06, 'max_bins': 128, 'keep_ratio': 0.25}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:53,287] Trial 14 finished with value: 2.171522135878781 and parameters: {'max_iter': 403, 'learning_rate': 0.0760466099928515, 'max_leaf_nodes': 238, 'max_depth': 6, 'min_samples_leaf': 19, 'l2_regularization': 5.90763072663626e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:54,648] Trial 15 finished with value: 2.156695843422553 and parameters: {'max_iter': 399, 'learning_rate': 0.049389338239450076, 'max_leaf_nodes': 250, 'max_depth': 6, 'min_samples_leaf': 19, 'l2_regularization': 1.0698318332546927e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:56,076] Trial 16 finished with value: 2.1448361207455533 and parameters: {'max_iter': 392, 'learning_rate': 0.028275839610256162, 'max_leaf_nodes': 207, 'max_depth': None, 'min_samples_leaf': 23, 'l2_regularization': 4.0836469214872055e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:38:59,438] Trial 17 finished with value: 2.815965134119164 and parameters: {'max_iter': 999, 'learning_rate': 0.02219435689293656, 'max_leaf_nodes': 202, 'max_depth': None, 'min_samples_leaf': 30, 'l2_regularization': 0.08485501187431774, 'max_bins': 128, 'keep_ratio': 0.25}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:39:01,496] Trial 18 finished with value: 2.1215274321942976 and parameters: {'max_iter': 602, 'learning_rate': 0.028367140797682055, 'max_leaf_nodes': 167, 'max_depth': None, 'min_samples_leaf': 23, 'l2_regularization': 4.648394343080063e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:39:03,495] Trial 19 finished with value: 2.1311354174836876 and parameters: {'max_iter': 589, 'learning_rate': 0.10650815312302372, 'max_leaf_nodes': 167, 'max_depth': 10, 'min_samples_leaf': 23, 'l2_regularization': 4.999578548075509e-05, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.117535401895665.
# [I 2025-10-15 02:39:05,768] Trial 20 finished with value: 2.1153865341027998 and parameters: {'max_iter': 737, 'learning_rate': 0.028675296993000848, 'max_leaf_nodes': 128, 'max_depth': None, 'min_samples_leaf': 26, 'l2_regularization': 3.718245551626237e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 20 with value: 2.1153865341027998.
# [I 2025-10-15 02:39:08,023] Trial 21 finished with value: 2.118766264654163 and parameters: {'max_iter': 737, 'learning_rate': 0.0332955948582202, 'max_leaf_nodes': 128, 'max_depth': None, 'min_samples_leaf': 26, 'l2_regularization': 2.9351856101319508e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 20 with value: 2.1153865341027998.
# [I 2025-10-15 02:39:11,081] Trial 22 finished with value: 2.0912389874333512 and parameters: {'max_iter': 771, 'learning_rate': 0.03876300470762144, 'max_leaf_nodes': 126, 'max_depth': None, 'min_samples_leaf': 27, 'l2_regularization': 2.969605430911148e-06, 'max_bins': 128, 'keep_ratio': 0.75}. Best is trial 22 with value: 2.0912389874333512.
# ...
# [I 2025-10-15 03:00:30,051] Trial 5 finished with value: 2.759452829242432 and parameters: {'n_estimators': 681, 'max_depth': 14, 'min_samples_leaf': 11, 'max_features': 0.4789196901078193, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:00:48,215] Trial 6 finished with value: 2.6615772470969925 and parameters: {'n_estimators': 886, 'max_depth': 10, 'min_samples_leaf': 1, 'max_features': 0.8235932881616793, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:00:58,873] Trial 7 finished with value: 3.3397166711626194 and parameters: {'n_estimators': 478, 'max_depth': 6, 'min_samples_leaf': 2, 'max_features': 0.9120954329667595, 'bootstrap': False, 'keep_ratio': 1.0}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:02,697] Trial 8 finished with value: 3.2767695391487806 and parameters: {'n_estimators': 368, 'max_depth': None, 'min_samples_leaf': 5, 'max_features': 0.9015906654375635, 'bootstrap': False, 'keep_ratio': 0.25}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:10,894] Trial 9 finished with value: 2.6791851418441177 and parameters: {'n_estimators': 524, 'max_depth': 14, 'min_samples_leaf': 4, 'max_features': 0.791758436095749, 'bootstrap': True, 'keep_ratio': 1.0}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:19,284] Trial 10 finished with value: 2.6898107643070053 and parameters: {'n_estimators': 794, 'max_depth': None, 'min_samples_leaf': 7, 'max_features': 0.67384311001737, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:28,098] Trial 11 finished with value: 2.737743063596014 and parameters: {'n_estimators': 602, 'max_depth': 8, 'min_samples_leaf': 1, 'max_features': 0.6312471814710695, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:35,750] Trial 12 finished with value: 2.716831473200333 and parameters: {'n_estimators': 595, 'max_depth': 12, 'min_samples_leaf': 6, 'max_features': 0.6117646428464648, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:42,442] Trial 13 finished with value: 2.650200287657731 and parameters: {'n_estimators': 494, 'max_depth': 12, 'min_samples_leaf': 3, 'max_features': 0.540623700805892, 'bootstrap': False, 'keep_ratio': 0.75}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:47,697] Trial 14 finished with value: 2.8738507840993406 and parameters: {'n_estimators': 648, 'max_depth': 6, 'min_samples_leaf': 1, 'max_features': 0.7150584970068702, 'bootstrap': True, 'keep_ratio': 0.35}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:51,908] Trial 15 finished with value: 2.940930773523476 and parameters: {'n_estimators': 750, 'max_depth': 8, 'min_samples_leaf': 8, 'max_features': 0.40161638610973227, 'bootstrap': False, 'keep_ratio': 0.25}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:01:57,466] Trial 16 finished with value: 2.8334551407380317 and parameters: {'n_estimators': 552, 'max_depth': 12, 'min_samples_leaf': 4, 'max_features': 0.573815853960495, 'bootstrap': False, 'keep_ratio': 0.5}. Best is trial 3 with value: 2.6094478576323423.
# [I 2025-10-15 03:02:07,265] Trial 17 finished with value: 2.601814224644703 and parameters: {'n_estimators': 821, 'max_depth': None, 'min_samples_leaf': 3, 'max_features': 0.7004800042984515, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 17 with value: 2.601814224644703.
# [I 2025-10-15 03:02:19,058] Trial 18 finished with value: 2.64861445859869 and parameters: {'n_estimators': 885, 'max_depth': None, 'min_samples_leaf': 5, 'max_features': 0.981072147796757, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 17 with value: 2.601814224644703.
# [I 2025-10-15 03:02:26,529] Trial 19 finished with value: 2.82507493572963 and parameters: {'n_estimators': 809, 'max_depth': None, 'min_samples_leaf': 12, 'max_features': 0.7104892632172559, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 17 with value: 2.601814224644703.
# [I 2025-10-15 03:02:30,424] Trial 20 finished with value: 2.824214731736584 and parameters: {'n_estimators': 445, 'max_depth': None, 'min_samples_leaf': 3, 'max_features': 0.8279803678681247, 'bootstrap': True, 'keep_ratio': 0.35}. Best is trial 17 with value: 2.601814224644703.
# [I 2025-10-15 03:02:38,427] Trial 21 finished with value: 2.601547758390485 and parameters: {'n_estimators': 613, 'max_depth': None, 'min_samples_leaf': 2, 'max_features': 0.6560323804039314, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 21 with value: 2.601547758390485.
# [I 2025-10-15 03:02:48,440] Trial 22 finished with value: 2.5974885065835345 and parameters: {'n_estimators': 738, 'max_depth': None, 'min_samples_leaf': 2, 'max_features': 0.6709963721565764, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 22 with value: 2.5974885065835345.
# [I 2025-10-15 03:03:00,195] Trial 23 finished with value: 2.5920288665589353 and parameters: {'n_estimators': 828, 'max_depth': None, 'min_samples_leaf': 2, 'max_features': 0.7410514227945543, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:03:10,905] Trial 24 finished with value: 2.593583134822555 and parameters: {'n_estimators': 746, 'max_depth': None, 'min_samples_leaf': 2, 'max_features': 0.7551477879709289, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:03:17,282] Trial 25 finished with value: 2.826280017083921 and parameters: {'n_estimators': 748, 'max_depth': None, 'min_samples_leaf': 5, 'max_features': 0.7362588888144889, 'bootstrap': True, 'keep_ratio': 0.5}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:03:25,003] Trial 26 finished with value: 2.8330316656109704 and parameters: {'n_estimators': 849, 'max_depth': None, 'min_samples_leaf': 4, 'max_features': 0.8565007706052514, 'bootstrap': True, 'keep_ratio': 0.25}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:03:35,920] Trial 27 finished with value: 2.593714542729702 and parameters: {'n_estimators': 764, 'max_depth': 14, 'min_samples_leaf': 2, 'max_features': 0.7716063496347391, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:03:44,009] Trial 28 finished with value: 2.6592640714916946 and parameters: {'n_estimators': 779, 'max_depth': 14, 'min_samples_leaf': 6, 'max_features': 0.7784832340438264, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:03:50,785] Trial 29 finished with value: 2.8322363627634553 and parameters: {'n_estimators': 676, 'max_depth': 14, 'min_samples_leaf': 4, 'max_features': 0.8894419458385407, 'bootstrap': True, 'keep_ratio': 0.35}. Best is trial 23 with value: 2.5920288665589353.
# [I 2025-10-15 03:04:02,914] Trial 30 finished with value: 2.59199710771798 and parameters: {'n_estimators': 858, 'max_depth': 14, 'min_samples_leaf': 2, 'max_features': 0.7382184404715405, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 30 with value: 2.59199710771798.
# [I 2025-10-15 03:04:14,975] Trial 31 finished with value: 2.5917839772773537 and parameters: {'n_estimators': 853, 'max_depth': 14, 'min_samples_leaf': 2, 'max_features': 0.7637238075551921, 'bootstrap': True, 'keep_ratio': 0.75}. Best is trial 31 with value: 2.5917839772773537.
# [I 2025-10-15 03:04:20,528] A new study created in memory with name: no-name-89df3971-ab07-4e9d-8ef2-85730e85b8ab
# [I 2025-10-15 03:04:20,726] Trial 0 finished with value: 3.097547476775786 and parameters: {'alpha': 0.0005798540228440976, 'l1_ratio': 0.32212094873676905, 'max_iter': 2248, 'keep_ratio': 0.5}. Best is trial 0 with value: 3.097547476775786.
# [I 2025-10-15 03:04:20,925] Trial 1 finished with value: 3.0983899918936046 and parameters: {'alpha': 0.0022183258107863245, 'l1_ratio': 0.6296263628638904, 'max_iter': 2373, 'keep_ratio': 0.35}. Best is trial 0 with value: 3.097547476775786.
# [I 2025-10-15 03:04:21,138] Trial 2 finished with value: 3.13613935338943 and parameters: {'alpha': 0.2563872350947084, 'l1_ratio': 0.5470311323634438, 'max_iter': 3075, 'keep_ratio': 0.35}. Best is trial 0 with value: 3.097547476775786.
# [I 2025-10-15 03:04:21,340] Trial 3 finished with value: 3.0876556939957993 and parameters: {'alpha': 0.1133847525965555, 'l1_ratio': 0.8445276025401911, 'max_iter': 4489, 'keep_ratio': 0.5}. Best is trial 3 with value: 3.0876556939957993.
# [I 2025-10-15 03:04:21,541] Trial 4 finished with value: 3.094260415730783 and parameters: {'alpha': 0.03912722931201038, 'l1_ratio': 0.5903374420965867, 'max_iter': 4131, 'keep_ratio': 0.5}. Best is trial 3 with value: 3.0876556939957993.
# [I 2025-10-15 03:04:21,738] Trial 5 finished with value: 2.9363626758236023 and parameters: {'alpha': 0.003015528729545592, 'l1_ratio': 0.60082122134591, 'max_iter': 4905, 'keep_ratio': 0.75}. Best is trial 5 with value: 2.9363626758236023.
# [I 2025-10-15 03:04:21,937] Trial 6 finished with value: 2.948208977411865 and parameters: {'alpha': 0.022968226241283887, 'l1_ratio': 0.7626964645655676, 'max_iter': 2461, 'keep_ratio': 1.0}. Best is trial 5 with value: 2.9363626758236023.
# [I 2025-10-15 03:04:22,152] Trial 7 finished with value: 2.9334998398426406 and parameters: {'alpha': 0.011918962381164532, 'l1_ratio': 0.8800085331332465, 'max_iter': 2364, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.9334998398426406.
# [I 2025-10-15 03:04:22,354] Trial 8 finished with value: 2.9372022515583844 and parameters: {'alpha': 0.00030558674531010405, 'l1_ratio': 0.6733297161649254, 'max_iter': 5344, 'keep_ratio': 0.75}. Best is trial 7 with value: 2.9334998398426406.
# [I 2025-10-15 03:04
 'keep_ratio': 0.75}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:26,779] Trial 25 finished with value: 4.0216000195549375 and parameters: {'alpha': 1.4081993657375926, 'l1_ratio': 0.8278327810670727, 'max_iter': 3422, 'keep_ratio': 0.25}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:26,984] Trial 26 finished with value: 2.930978789836471 and parameters: {'alpha': 0.20262233752622985, 'l1_ratio': 0.9482948702152255, 'max_iter': 4656, 'keep_ratio': 0.75}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:27,193] Trial 27 finished with value: 2.924614292132327 and parameters: {'alpha': 0.08519062019578345, 'l1_ratio': 0.7369154987057671, 'max_iter': 3565, 'keep_ratio': 0.75}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:27,418] Trial 28 finished with value: 4.801625872690969 and parameters: {'alpha': 2.2963197132104725, 'l1_ratio': 0.8891464023712181, 'max_iter': 4189, 'keep_ratio': 0.75}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:27,626] Trial 29 finished with value: 3.2442505085868376 and parameters: {'alpha': 0.4828785541020512, 'l1_ratio': 0.7028176978724212, 'max_iter': 2088, 'keep_ratio': 0.5}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:27,831] Trial 30 finished with value: 2.945048569033794 and parameters: {'alpha': 0.05379114715838323, 'l1_ratio': 0.44129663896604054, 'max_iter': 3179, 'keep_ratio': 1.0}. Best is trial 18 with value: 2.918934668086017.
# [I 2025-10-15 03:04:28,035] Trial 31 finished with value: 2.9233962337567463 and parameters: {'alpha': 0.07998964811556329, 'l1_ratio': 0.8007620331505994, 'max_iter': 5059, 'keep_ratio': 0.75}. Best is trial 18 with value: 2.918934668086017.
# [Fold 4/4] RMSE HGBR=2.1630 (#15) | XGB=2.1934 (#15) | RF=2.5168 (#15) | ENet=2.7244 (#15)
#
#  >>>>> OOF Summary <<<<<
# HGBR  OOF RMSE: 2.266829 | mean=2.241262 ± 0.339502 | median #feats=15
# XGB   OOF RMSE: 2.029570 | mean=2.021950 ± 0.175696 | median #feats=20
# RF    OOF RMSE: 2.551320 | mean=2.546760 ± 0.152473 | median #feats=17
# ENet  OOF RMSE: 2.827183 | mean=2.813322 ± 0.279609 | median #feats=17
#
#  >>>>> FINAL MODEL <<<<<
# Selected: XGB with OOF RMSE=2.029570
#
#  Saved: /content/model/model.pkl
# Predicciones: /content/target_pred.csv

# %%
# generation of model manifest.json
manifest = {
  "manifest_version": "1.0",
  "model_version": datetime.now(timezone.utc).strftime("%Y%m%d-%H%M%S"),
  "model_type": chosen_name,
  "features": features_final,
  "metrics": {
    "oof_rmse": round(best["oof_rmse"], 6),
    "cv_scheme": f"nested {N_OUTER}x{N_INNER}",
    "notes": "OOF = Out-of-Fold RMSE (outer test)."
  },
  "training": {
    "created_utc": datetime.now(timezone.utc).strftime("%Y-%m-%dT%H:%M:%SZ"),
    "code_ref": "notebooks/multivariate_regression_training.ipynb",
    "seed": SEED,
    "optuna": {
      "sampler": "TPE",
      "trials": {"XGB": N_TRIALS_XGB, "HGBR": N_TRIALS_HGBR, "RF": N_TRIALS_RF, "ENet": N_TRIALS_ENET},
      "timeout_sec": TIMEOUT_SECS
    }
  }
}

MANIFEST_OUT.write_text(json.dumps(manifest, indent=2), encoding="utf-8")
print("\n=== MODEL MANIFEST (copy-paste) ===")
print(json.dumps(manifest, indent=2))

print("\n=== FEATURES SELECCIONADAS (final) ===")
print(f"Total: {len(features_final)}")
print(features_final[:50])
